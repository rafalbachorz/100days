# %% [markdown]
# ![image.png](attachment:30c34d10-60dc-4568-8c68-7e9cf8199c5f.png)

# %% [markdown]
# ### The objective of the puzzle is to move the entire stack to another rod, obeying the following simple rules:
# * Only one disk can be moved at a time.
# * Each move consists of taking the upper disk from one of the stacks and placing it on top of another stack or on an empty rod.
# * No larger disk may be placed on top of a smaller disk.

# %% [markdown]
# ## algorithm

# %% [markdown]
# ![image.png](attachment:acb4db37-5203-49ca-8003-ab58d39adfd0.png)

# %%
def hanoi(height, left='left', right='right', middle='middle'):
    if height:
        if (debug):
            print('!!! 1 !!!', height, left, right, middle)
        hanoi(height - 1, left, middle, right)
        if (output):
            print(left, '=>', right)
        if (debug):
            print('!!! 2 !!!', height, left, right, middle)
        hanoi(height - 1, middle, right, left)
        
def memoize(f):
    h = {}
    def g(*u):
        if u in h:
            return h[u]
        else:
            r = f(*u)
            h[u] = r
            return r
    return g        

@memoize
def hanoiM(height, left='left', right='right', middle='middle'):
    if height:
        if (debug):
            print('!!! 1 !!!', height, left, right, middle)
        hanoiM(height - 1, left, middle, right)
        if (output):
            print(left, '=>', right)
        if (debug):
            print('!!! 2 !!!', height, left, right, middle)
        hanoiM(height - 1, middle, right, left)

# %%
import time
output, debug = False, False
for param in [1,5,10,15,17,18,19]:
    for f in [hanoi, hanoiM]:
        t1 = time.clock()
        f(param)
        t2 = time.clock()
        print( f.__name__, param, 1000 * (t2 - t1) )
    print()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   import sys
# hanoi 1 0.02807700001028479
# g 1 0.0025520000122014608
#
# hanoi 5 0.013128000006190632
# g 5 0.00255300000162606
#
# hanoi 10 0.31250100001045666
# g 10 0.0032819999944422307
#
# hanoi 15 12.517904000006297
# g 15 0.0032819999944422307
#
# hanoi 17 49.6621200000078
# g 17 0.0032820000086530854
#
# hanoi 18 87.25229600000262
# g 18 0.0032820000086530854
#
# hanoi 19 181.49666400000797
# g 19 0.028442000001405177

# %%
#hanoi(1, debug=False)
#hanoi(100)

# %%
hanoi(2, debug=True)

# %%
hanoi(3, debug=True)

# %%
hanoi(4, debug=True)

# %% [markdown]
# * the case from the picture: 8 disks on the rod

# %%
hanoi(8, debug=False)

# %% [markdown]
# * Workshop for PSI Metals - first attempts of AI
# * Unbelivable that this can be solved with 3-5 lines of code
# * Different behaviour for even and odd number of disks
# ** even: left -> middle (...)
# ** odd: left -> right (...)
# * https://en.wikipedia.org/wiki/Tower_of_Hanoi
# * There are also less sophisticated, iterative algotithms
# * Animation: http://towersofhanoi.info/Animate.aspx
